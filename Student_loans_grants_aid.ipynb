# %% [markdown]
# # National Student Loans, Aid and Grants

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import style
style.use('ggplot')
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from matplotlib import style
from matplotlib import pylab
style.use('ggplot')

# %%
file1_csv = "student_money.csv"
student_money_df = pd.read_csv(file1_csv)

# %%
student_money_df
# Out:
#    Years    Aid  Grants  Loans  Total
# 0   2000  12140    7310   8640  28090
# 1   2004  12730    7400   9130  29260
# 2   2008  14890    8310  10910  34110
# 3   2012  16540    9840  10760  37140
# 4   2016  18550   11550  11350  41450

# %%
# Plot the world and one country averages as a line chart
years = student_money_df["Years"]
plt.figure(figsize=(10,8))
plt.title("Student Cost")
Aid, = plt.plot(years, student_money_df["Aid"], label="Student Aid", color="blue")
Grants, = plt.plot(years, student_money_df["Grants"], label="Grants", color="green")
Loans, = plt.plot(years, student_money_df["Loans"], label="Loans", color="red")
Total, = plt.plot(years, student_money_df["Total"], label="Total", color="purple")
# Create a legend for our chart

plt.legend(handles=[Aid, Grants, Loans, Total], loc="best")

# Show the chart

plt.savefig("Student_Cost.png")
plt.show()

# %%
years = student_money_df["Years"]
plt.figure(figsize=(12,10))
plt.title("Student Loans")
Loans, = plt.plot(years, student_money_df["Loans"], label="Loans", color="red")

# Create a legend for our chart

plt.legend(handles=[Loans], loc="best")

# Show the chart

plt.savefig("Student_Loans.png")
plt.show()

# %%
file2_csv = "Enrollment_4_Yr.csv"
Enrollment_4_yrDegree_df = pd.read_csv(file2_csv)

# %%
Enrollment_4_yrDegree_df
# Out:
#     Years  Enrollment
# 0    2005    13523496
# 1    2006    13820133
# 2    2007    14167699
# 3    2008    14736205
# 4    2009    15586311
# 5    2010    16373687
# 6    2011    16931363
# 7    2012    16979168
# 8    2013    16796285
# 9    2014    16738709
# 10   2015    16720274
# 11   2016    16986541

# %%
year = Enrollment_4_yrDegree_df["Years"] 
plt.figure(figsize=(12,7))
ax, = plt.plot(year, Enrollment_4_yrDegree_df["Enrollment"], color = "orange")

# plt.legend(handles=[ax], loc="best")
plt.title("4yr Colleges Enrollment")
# Show the chart
plt.legend(handles=[ax], loc="best")

plt.savefig("National_Enrollment.png")

# %%
file3_csv = "Public_Revenue.csv"
Public_revenue_df = pd.read_csv(file3_csv)
file4_csv = "Private_Revenue.csv"
Private_revenue_df = pd.read_csv(file4_csv)

# %%
Public_revenue_df
# Out:
#     Year   Revenues
# 0   2004  218980633
# 1   2005  229496968
# 2   2006  240691924
# 3   2007  262122937
# 4   2008  266648983
# 5   2009  261526673
# 6   2010  295135575
# 7   2011  314327941
# 8   2012  308896042
# 9   2013  317860919
# 10  2014  342158481
# 11  2015  337013316
# 12  2016  354029746

# %%
Private_revenue_df
# Out:
#     Year  Revenues
# 0   2004  11814981
# 1   2005  14243363
# 2   2006  15984138
# 3   2007  17622308
# 4   2008  20007191
# 5   2009  23405149
# 6   2010  29600362
# 7   2011  33826737
# 8   2012  32196642
# 9   2013  29660603
# 10  2014  27322409
# 11  2015  24014297
# 12  2016  20812871

# %%
year = Public_revenue_df["Year"] 
plt.figure(figsize=(8,6))
public, = plt.plot(year, Public_revenue_df["Revenues"], color = "Green")
# plt.legend(handles=[ax], loc="best")
plt.title("Public Revenue")
# Show the chart
plt.legend(handles=[public], loc="best")

plt.savefig("Public_Revenue.png")

# %%
year = Public_revenue_df["Year"] 
#plt.figure(figsize=(8,6))
private, = plt.plot(year, Private_revenue_df["Revenues"], color = "Purple")
# plt.legend(handles=[ax], loc="best")
plt.title("Private Revenue")

# Show the chart
plt.legend(handles=[private], loc="best")

plt.savefig("Private_Revenue.png")

# %%
file5_csv = "Trilogy_Enrollment.csv"
Trilogy_Enrollment_df = pd.read_csv(file5_csv)

# %%
year = Public_revenue_df["Year"] 
#plt.figure(figsize=(8,6))
private, = plt.plot(year, Private_revenue_df["Revenues"], color = "Purple")
# plt.legend(handles=[ax], loc="best")
#plt.title("Private Revenue")

# Show the chart
#plt.legend(handles=[private], loc="best")

plt.savefig("Private_Revenue_Hook.png")

# %%
Trilogy_Enrollment_df
# Out:
#    Quarters  Enrollment
# 0         1        5000
# 1         2        6000
# 2         3        7000
# 3         4        8000
# 4         5        9000
# 5         6       10000
# 6         7       11000

# %%
time = Trilogy_Enrollment_df["Quarters"] 
plt.figure(figsize=(8,6))
Trilogy, = plt.plot(time, Trilogy_Enrollment_df["Enrollment"], color = "Blue")
# plt.legend(handles=[ax], loc="best")
#plt.title("Trilogy Enrollment")
# Show the chart
#plt.legend(handles=[Trilogy], loc="best")

plt.savefig("Trilogy_HOOK_Pic.png")

# %%
time = Trilogy_Enrollment_df["Quarters"] 
plt.figure(figsize=(8,6))
Trilogy, = plt.plot(time, Trilogy_Enrollment_df["Enrollment"], color = "Blue")
# plt.legend(handles=[ax], loc="best")
plt.title("Trilogy BootCamps Enrollment", fontsize = 24)
plt.xlabel('# of Quarters', fontsize=20)
plt.ylabel('Enrollment', fontsize=20)
# Show the chart
#plt.legend(handles=[Trilogy], loc="best")

plt.savefig("Trilogy_conclusion_Pic.png")
